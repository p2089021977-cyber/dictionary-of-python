# %%
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.countplot(df['smoker'])
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
df.isnull().sum()/len(df)
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df.sample()
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 218        7.74  1.44  Male    Yes  Sat  Dinner     2

# %%
sns.barplot(df['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(df['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.countplot(df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(df['smoker'])
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
sns.violinplot(df['total_bill'], color='yellow')
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='tip',hue ="smoker",data=df,color='orange')
plt.title('barplot of sex vs tips')
plt.show()
# Out:
# /tmp/ipython-input-3538979509.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:orange'` for the same effect.
#
#   sns.barplot(x='sex',y='tip',hue ="smoker",data=df,color='orange')

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df)
plt.title('data ki pairplot')
plt.show()

# %%
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3345567481.py in <cell line: 0>()
# ----> 1 sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker")
#
# NameError: name 'tips' is not defined

# %%
sns.violinplot(x='sex',y='tip',data=df,hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red  ', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
